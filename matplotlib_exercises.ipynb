# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from random import randint
import random
import pandas as pd

# %%
#### 1
#Use matplotlib to plot the following equation:
#
# y = x^2 - x + 2

# You'll need to write the code that generates the x and y points.
# Add an anotation for the point 0, 0, the origin.

x = range(-100, 100)

y = [(x ** 2 - x + 2) for x in x]

plt.plot(x,y)

plt.title('$y = x^2 - x + 2$')

plt.xlabel('$x$')
plt.ylabel('$y$')

plt.annotate('origin', xy = (0, 0), xytext = (0, 2000), arrowprops = {})
# Out:
# Text(0, 2000, 'origin')

# %%
f(num) for num in x

# %%
# 2
# Create and label 4 separate charts for the following equations 
# (choose a range for x that makes sense)

# Y = sqrrt of x
# y = x^3
# y = 2^x
# y = 1/(x+1)

x1 = range(1, 10)
x2 = [x * 0.1 for x in range(0,150)]
x3 = range(0,20)
x4 = range(1, 100)
list(x)
y1 = np.sqrt(x1)
y2 = [num ** 3 for num in x2]
y3 = [2 ** num for num in x3]
y4 = [1/(num + 1) for num in x4]

plt.figure(figsize = (9, 7))
plt.suptitle('questions 2, 3, and 4')

plt.subplot(221)
plt.plot(x1, y1, label = '$\sqrt{x}$', color = 'b', ls = '-.')
plt.title('$\sqrt{x}$')

plt.subplot(222)
plt.plot(x2, y2, color= "g", label='$x^{3}$', ls = '-')
plt.title('$x^3$')

plt.subplot(223)
plt.plot(x3,y3, color = 'r', ls = '--', label= '$2^{x}$')
plt.title('$2^{x}$')


plt.subplot(224)
plt.plot(x4, y4, color = 'grey', ls = ':', label= '$1/(x+1)$')
plt.title('$1/(x+1)$')


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (8, 6))


plt.plot(x1, y1, label = '$\sqrt{x}$', color = 'b', ls = '-.')
plt.plot(x2, y2, color= "g", label='$x^{3}$', ls = '-')
plt.plot(x3, y3, color = 'r', ls = '--', label= '$2^{x}$')
plt.plot(x4, y4, color = 'grey', ls = ':', label= '$1/(x+1)$')

plt.ylim(0, 10)
plt.xlim(0, 10)

plt.ylabel('$Y$')
plt.xlabel('$X$')
plt.title('Ford\'s Functions')
plt.legend()

plt.show()
